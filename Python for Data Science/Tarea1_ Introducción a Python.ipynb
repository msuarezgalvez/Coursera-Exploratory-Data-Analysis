# %% [markdown]
# # Python para Data Science

# %% [markdown]
# ![Python.jpg](attachment:Python.jpg)

# %% [markdown]
# # Parte 1: Introducción a Python

# %% [markdown]
# Python es un lenguaje de programación interpretado, orientado a objetos y de alto nivel. Python es uno de los lenguajes más populares y de los más utilizados en Machine learning, desarrollo web, desarrollo de videojuegos,etc
#
# Python es popular por su sintaxis simple y directa. Algunas de las razones por las que es uno de los lenguajes mas populares:
# - Es open-source
# - Es fácil de aprender. Su sintaxis es muy fácil y fácil de interpretar
# - Es portable
# - Tiene un montón de librerias desarrolladas
# - Hay una comunidad muy activa de desarrolladores

# %% [markdown]
# ![Growth-of-major-programming-languages.jpg](attachment:Growth-of-major-programming-languages.jpg)

# %% [markdown]
# ### Preparación del entorno de Python

# %% [markdown]
# **Instalación de recursosos básicos:**
# 1. Python 3 o superior: (https://www.python.org/downloads/)
# 2. IDE: Pycharm (https://www.jetbrains.com/pycharm/), Jupyter Notebook, VisualStudio de Microsoft, etc.
# 3. Distribución de librerias externas: Anaconda (https://www.anaconda.com/products/individual)
#
# **Para la instalacion de librerias:**
# - Desde el prompt de Anaconda: conda install 'libreria'
# - Desde cmd: python install 'libreria'
#
# **Recursos de soporte**
# - Stackoverflow (https://stackoverflow.com/questions/tagged/python)
# - O'Reilly (https://www.oreilly.com/)
# - Kaggle, TowardsDataScience (Medium), etc.

# %% [markdown]
# #### **Ejercicio 1**
# Instalación de Anaconda, y de la libreria seaborn

# %% [markdown]
# ### Sintaxis de Python

# %%
## A continuación se muestra un ejemplo de un codigo de Python

#Pasar los kilometros a millas
kilometers = float(input("Mete el valor que busques en kilometros: "))

# conversion a factor
conv_fac = 0.621371

# calculate miles
miles = kilometers * conv_fac
print('%0.2f kilometros es igual a %0.2f millas' %(kilometers,miles))

# %% [markdown]
# #### Ejercicio 2

# %%
# Vamos a programar un codigo que haga la suma de dos números. Deberas completar la parte que aparece comentada con '##'

## genera la variable num1 que es igual al decimal de 1
## la variable num2 deberá introducirse por el usuario y transformarse a decimal

# Suma de ambas variables
suma = num1 + num2

# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, suma))
